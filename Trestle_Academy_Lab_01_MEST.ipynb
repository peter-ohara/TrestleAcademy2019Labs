# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
housing_dirty_1 = pd.read_csv('../data/housing_1_dirty.csv')

# %%
housing_dirty_2 = pd.read_excel('../data/housing_2_dirty.xlsx')

# %%
housing_dirty_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 4 columns):
# id                 20640 non-null int64
# longitude          20639 non-null float64
# latitude           20640 non-null float64
# ocean_proximity    20636 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 645.1+ KB

# %%
housing_dirty_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20567 entries, 0 to 20566
# Data columns (total 8 columns):
# id                    20567 non-null int64
# housing_median_age    20566 non-null float64
# total_rooms           20564 non-null float64
# total_bedrooms        20359 non-null float64
# population            20564 non-null float64
# households            20566 non-null float64
# median_income         20567 non-null float64
# median_house_value    20565 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 1.3 MB

# %%
data = pd.merge(housing_dirty_1, housing_dirty_2, on="id")
data
# Out:
#           id  longitude  latitude ocean_proximity  housing_median_age  \
# 0          1    -122.23     37.88        NEAR BAY                41.0
# 1          2    -122.22     37.86        NEAR BAY                21.0
# 2          3    -122.24     37.85        NEAR BAY                52.0
# 3          4    -122.25     37.85        NEAR BAY                52.0
# 4          5    -122.25     37.85        NEAR BAY                52.0
# 5          6    -122.25     37.85        NEAR BAY                52.0
# 6          7     122.25     37.84        NEAR BAY                52.0
# 7          8    -122.25     37.84        NEAR BAY                52.0
# 8          9    -122.26     37.84        NEAR BAY                42.0
# 9         10    -122.25     37.84        NEAR BAY                52.0
# 10        11    -122.26     37.85        NEAR BAY                52.0
# 11        12    -122.26     37.85     nNEAR OCEAN                52.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20567 entries, 0 to 20566
# Data columns (total 11 columns):
# id                    20567 non-null int64
# longitude             20566 non-null float64
# latitude              20567 non-null float64
# ocean_proximity       20563 non-null object
# housing_median_age    20566 non-null float64
# total_rooms           20564 non-null float64
# total_bedrooms        20359 non-null float64
# population            20564 non-null float64
# households            20566 non-null float64
# median_income         20567 non-null float64
# median_house_value    20565 non-null float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.9+ MB

# %%
data.isnull().sum()
# Out:
# id                      0
# longitude               1
# latitude                0
# ocean_proximity         4
# housing_median_age      1
# total_rooms             3
# total_bedrooms        208
# population              3
# households              1
# median_income           0
# median_house_value      2
# dtype: int64

# %%
data[data["total_bedrooms"].isna()].head()
# Out:
#       id  longitude  latitude ocean_proximity  housing_median_age  \
# 290  291    -122.16     37.77        NEAR BAY                47.0
# 341  342    -122.17     37.75        NEAR BAY                38.0
# 538  539    -122.28     37.78        NEAR BAY                29.0
# 563  564    -122.24     37.75        NEAR BAY                45.0
# 696  697    -122.10     37.69        NEAR BAY                41.0
#
#      total_rooms  total_bedrooms  population  households  median_income  \
# 290       1256.0             NaN       570.0       218.0         4.3750
# 341        992.0             NaN       732.0       259.0         1.6196
# 538       5154.0             NaN      3741.0      1273.0         2.5762
# 563        891.0             NaN       384.0       146.0         4.9489
# 696        746.0             NaN       387.0       161.0         3.9063
#
#      median_house_value
# 290            161900.0
# 341             85100.0
# 538            173400.0
# 563            247100.0
# ...

# %%
data.head()
# Out:
#    id  longitude  latitude ocean_proximity  housing_median_age  total_rooms  \
# 0   1    -122.23     37.88        NEAR BAY                41.0        880.0
# 1   2    -122.22     37.86        NEAR BAY                21.0       7099.0
# 2   3    -122.24     37.85        NEAR BAY                52.0       1467.0
# 3   4    -122.25     37.85        NEAR BAY                52.0       1274.0
# 4   5    -122.25     37.85        NEAR BAY                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0

# %%
data["total_bedrooms"].describe()
# Out:
# count    20359.000000
# mean       538.399872
# std        421.724100
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
data["ocean_proximity"].value_counts(dropna=False)
# Out:
# <1H OCEAN      9131
# INLAND         6478
# NEAR OCEAN     2655
# NEAR BAY       2287
# nNEAR OCEAN       7
# ISLAND            5
# NaN               4
# Name: ocean_proximity, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)

# %%
regr.fit(data.drop(columns="median_house_value"), data["median_house_value"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-1c09676cdb67> in <module>
# ----> 1 regr.fit(data.drop(columns="median_house_value"), data["median_house_value"])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
# ...
